# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy


# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 605

# %%
cities[:5]
# Out:
# ['puerto ayora', 'saskylakh', 'port elizabeth', 'mandalgovi', 'vardo']

# %%
 # Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
city="saskylakh"
output=requests.get(query_url + city).json()
output
# Out:
# {'coord': {'lon': 114.0833, 'lat': 71.9167},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02n'}],
#  'base': 'stations',
#  'main': {'temp': -33.6,
#   'feels_like': -38.29,
#   'temp_min': -33.6,
#   'temp_max': -33.6,
#   'pressure': 1027,
#   'humidity': 79,
#   'sea_level': 1027,
#   'grnd_level': 1026},
#  'visibility': 10000,
#  'wind': {'speed': 1.12, 'deg': 355, 'gust': 1.38},
#  'clouds': {'all': 18},
#  'dt': 1614460602,
#  'sys': {'country': 'RU', 'sunrise': 1614470799, 'sunset': 1614503172},
#  'timezone': 32400,
#  'id': 2017155,
#  'name': 'Saskylakh',
#  'cod': 200}

# %%
# set up lists to hold reponse info
lat = []
temp = []
humidity=[]
long=[]
cloudiness=[]
country=[]
date=[]
wind_speed=[]
cityname=[]
# Loop through the list of cities and perform a request for data on each
for x in cities:
    try:
        response = requests.get(query_url + x).json()
        lat.append(response['coord']['lat'])
        temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        long.append(response['coord']['lon'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        cityname.append(x)
        print(x)
    except:
        print("city not found")
# Out:
# puerto ayora
# saskylakh
# port elizabeth
# mandalgovi
# vardo
# avarua
# assiniboia
# city not found
# cherskiy
# nikolskoye
# namibe
# city not found
# qaanaaq
# kholodnyy
# klaksvik
# ushuaia
# jiaojiang
# ponta do sol
# sinnamary
# kodiak
# rikitea
# urbano santos
# berbera
# busselton
# okhotsk
# marsh harbour
# barrow
# la ronge
# waingapu
# jamestown
# city not found
# kloulklubed
# city not found
# butaritari
# city not found
# saint george
# albany
# maun
# mataura
# port alfred
# city not found
# chapais
# kaitangata
# granada
# saint-philippe
# pevek
# sambava
# chokurdakh
# dunedin
# kovdor
# san pedro
# ahipara
# victoria
# atuona
# new norfolk
# tiksi
# ola
# narsaq
# city not found
# hermanus
# east london
# yellowknife
# bluff
# arraial do cabo
# cayenne
# lompoc
# mandan
# kavaratti
# santa cruz
# santa maria
# carnarvon
# malakal
# la asuncion
# cao bang
# mitu
# torbay
# baykit
# city not found
# camaiore
# sur
# muriwai beach
# kavieng
# los llanos de aridane
# vaini
# norman wells
# petit-bourg
# viedma
# baruun-urt
# severo-kurilsk
# bathsheba
# barcelos
# mahuva
# bandarbeyla
# lakes entrance
# peterhead
# koulamoutou
# thompson
# bredasdorp
# esperance
# lorengau
# bubaque
# narayangarh
# castro
# mahebourg
# chuy
# domoni
# palu
# gat
# city not found
# tautira
# city not found
# port moresby
# kapaa
# cape town
# faanui
# knysna
# nhulunbuy
# isangel
# plessisville
# puri
# mossendjo
# saldanha
# city not found
# city not found
# darhan
# bairiki
# abu zabad
# ribeira grande
# kalabo
# leningradskiy
# cabo san lucas
# city not found
# hambantota
# sal rei
# skegness
# inhambane
# hammerfest
# tuyen quang
# kahului
# ambatolampy
# dikson
# kalmunai
# punta arenas
# wanning
# margate
# chabahar
# solnechnyy
# longyearbyen
# pangnirtung
# ilave
# haines junction
# mali
# energeticheskiy
# seymchan
# kruisfontein
# altay
# cairns
# egvekinot
# xihe
# vao
# poya
# provideniya
# vestmannaeyjar
# quatre cocos
# acapulco
# cidreira
# almaznyy
# hobart
# kimberley
# colonia
# hithadhoo
# hilo
# hobyo
# pisco
# tuktoyaktuk
# beloha
# bethel
# yanam
# city not found
# san ramon de la nueva oran
# city not found
# maloco
# kishi
# sibut
# golfito
# byron bay
# saginaw
# aksu
# chipinge
# pailon
# blairmore
# cabinda
# port-gentil
# emerald
# huntsville
# thinadhoo
# itoman
# moengo
# aripuana
# henties bay
# verkhnyaya toyma
# ust-kuyga
# city not found
# barddhaman
# lamu
# novobelokatay
# cheremukhovo
# nizhniy tsasuchey
# tonantins
# savonlinna
# sept-iles
# fort nelson
# filadelfia
# juneau
# manaus
# otjimbingwe
# butte
# kihei
# camacha
# tromso
# dolores
# flinders
# minsk
# kiruna
# kieta
# mackay
# ventspils
# hohhot
# city not found
# gulu
# city not found
# kibala
# grand gaube
# city not found
# city not found
# anadyr
# christchurch
# suntar
# zomba
# city not found
# kastamonu
# shihezi
# jos
# burnie
# san onofre
# yamada
# north augusta
# hokitika
# orcopampa
# turayf
# naliya
# mitsamiouli
# san patricio
# taltal
# pimenta bueno
# kamskiye polyany
# paredon
# curup
# gushikawa
# cap malheureux
# labuhan
# kyshtovka
# ketchikan
# lata
# gusau
# city not found
# blagoyevo
# havoysund
# edson
# gizo
# minbu
# bardiyah
# port hawkesbury
# beidao
# port blair
# cockburn town
# tilichiki
# dutse
# maloy
# papara
# kununurra
# erenhot
# iisalmi
# iwanai
# asau
# perth
# almeirim
# bosaso
# manjacaze
# santa vitoria do palmar
# shitkino
# cafarnaum
# krasnoselkup
# olinda
# hirara
# city not found
# mkushi
# faya
# usinsk
# shimoda
# coihaique
# hattiesburg
# griffith
# maniitsoq
# natal
# city not found
# mahajanga
# simplicio mendes
# shagonar
# golub-dobrzyn
# carballo
# houma
# city not found
# epe
# vestmanna
# soledad
# pasighat
# teya
# chicama
# ulladulla
# massakory
# durban

# %%
weather_df=pd.DataFrame({"City":cityname,"Lat":lat,"Lng":long,"Max Temp":temp,"Humidity":humidity,
                        "Cloudiness":cloudiness, "Wind Speed":wind_speed,"Country":country,"Date":date})
weather_df
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      puerto ayora  -0.7393  -90.3518     28.00        78          40
# 1         saskylakh  71.9167  114.0833    -33.23        77          35
# 2    port elizabeth -33.9180   25.5701     21.00        83          90
# 3        mandalgovi  45.7625  106.2708    -14.80        65           0
# 4             vardo  70.3705   31.1107     -0.68        94         100
# ..              ...      ...       ...       ...       ...         ...
# 545            teya  60.3778   92.6267    -26.39        84         100
# 546         chicama  -7.8447  -79.1469     24.00        73           0
# 547       ulladulla -35.3500  150.4667     20.00        94          20
# 548       massakory  12.9960   15.7293     25.29        16           0
# 549          durban -29.8579   31.0292     23.33        88           0
#
#      Wind Speed Country        Date
# 0          5.14      EC  1614461246
# 1          1.23      RU  1614461247
# 2          5.66      ZA  1614461247
# 3          3.25      MN  1614461247
# 4          6.97      NO  1614461247
# ..          ...     ...         ...
# 545        2.81      RU  1614461624
# 546        3.09      PE  1614461624
# 547        2.06      AU  1614461624
# 548        5.68      TD  1614461624
# 549        0.85      ZA  1614461625
#
# [550 rows x 9 columns]

# %%
weather_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  550.000000  550.000000  550.000000  550.000000  550.000000  550.000000
# mean    19.207466   22.429122   11.372145   74.178182   50.330909    3.491055
# std     32.987624   90.024039   17.492188   19.823012   38.810402    2.553127
# min    -54.800000 -179.166700  -37.930000    5.000000    0.000000    0.150000
# 25%     -7.851600  -57.648775    1.400000   67.000000    7.000000    1.540000
# 50%     20.993050   25.328300   18.115000   79.000000   48.500000    3.015000
# 75%     47.816675  102.217575   25.000000   88.000000   90.000000    4.630000
# max     78.218600  178.416700   33.000000  100.000000  100.000000   17.570000
#
#                Date
# count  5.500000e+02
# mean   1.614462e+09
# std    9.231741e+01
# min    1.614461e+09
# 25%    1.614461e+09
# 50%    1.614462e+09
# 75%    1.614462e+09
# max    1.614462e+09

# %%
weather_df.loc[weather_df["Humidity"]>100]
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
#  Plotting the Data

# %%
x_axis2 = weather_df['Lat']
y_axis2 = weather_df['Max Temp']

plt.scatter(x_axis2, y_axis2)
plt.title("City Lattitude vs Max Tempature")
plt.xlabel("Lattitude")
plt.ylabel("Max Tempature(F)")
plt.show()

# %%
x_axis2 = weather_df['Lat']
y_axis2 = weather_df['Humidity']

plt.scatter(x_axis2, y_axis2)
plt.title("City Lattitude vs Humidity")
plt.xlabel("Lattitude")
plt.ylabel("Humidity(%)")
plt.show()

# %%
x_axis2 = weather_df['Lat']
y_axis2 = weather_df['Humidity']

plt.scatter(x_axis2, y_axis2)
plt.title("City Lattitude vs Humidity")
plt.xlabel("Lattitude")
plt.ylabel("Humidity(%)")
plt.show()

# %%
northern_df=weather_df.loc[weather_df["Lat"]>=0]
northern_df
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 1     saskylakh  71.9167  114.0833    -33.23        77          35
# 3    mandalgovi  45.7625  106.2708    -14.80        65           0
# 4         vardo  70.3705   31.1107     -0.68        94         100
# 6    assiniboia  49.6334 -105.9845    -18.00        60         100
# 7      cherskiy  68.7500  161.3000    -33.74        85          33
# ..          ...      ...       ...       ...       ...         ...
# 542   vestmanna  62.1564   -7.1664      8.00        87          90
# 543     soledad  10.9184  -74.7646     29.00        65           0
# 544    pasighat  28.0667   95.3333     18.05        58          40
# 545        teya  60.3778   92.6267    -26.39        84         100
# 548   massakory  12.9960   15.7293     25.29        16           0
#
#      Wind Speed Country        Date
# 1          1.23      RU  1614461247
# 3          3.25      MN  1614461247
# 4          6.97      NO  1614461247
# 6          4.63      CA  1614461473
# 7          0.51      RU  1614461473
# ..          ...     ...         ...
# 542        7.20      FO  1614461623
# 543        8.23      CO  1614461623
# 544        1.39      IN  1614461623
# 545        2.81      RU  1614461624
# 548        5.68      TD  1614461624
#
# [375 rows x 9 columns]

# %%
southern_df=weather_df.loc[weather_df["Lat"]<0]
southern_df
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        puerto ayora  -0.7393  -90.3518     28.00        78          40
# 2      port elizabeth -33.9180   25.5701     21.00        83          90
# 5              avarua -21.2078 -159.7750     26.00        94          75
# 9              namibe -15.1961   12.1522     21.04        78          42
# 13            ushuaia -54.8000  -68.3000     26.00        19           0
# ..                ...      ...       ...       ...       ...         ...
# 535         mahajanga -15.7167   46.3167     25.00       100          20
# 536  simplicio mendes  -7.8539  -41.9103     21.96        95          86
# 546           chicama  -7.8447  -79.1469     24.00        73           0
# 547         ulladulla -35.3500  150.4667     20.00        94          20
# 549            durban -29.8579   31.0292     23.33        88           0
#
#      Wind Speed Country        Date
# 0          5.14      EC  1614461246
# 2          5.66      ZA  1614461247
# 5          6.69      CK  1614461294
# 9          2.76      AO  1614461473
# 13         6.17      AR  1614461474
# ..          ...     ...         ...
# 535        1.54      MG  1614461621
# 536        1.71      BR  1614461621
# 546        3.09      PE  1614461624
# 547        2.06      AU  1614461624
# 549        0.85      ZA  1614461625
#
# [175 rows x 9 columns]

# %%
#   Linear Regression

# %%
x_values = northern_df['Lat']
y_values = northern_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,-30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: -0.8518672370443316

# %%
x_values = southern_df['Lat']
y_values = southern_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,12.5),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.49878134564906995

# %%
x_values = northern_df['Lat']
y_values = northern_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,-30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.3504704433521465

# %%
x_values = southern_df['Lat']
y_values = southern_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,12.5),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.2308621701477649
